# %%
# %pylab nbagg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ls -al
# Out:
# total 34256
# drwxr-xr-x  3 jerome jerome    4096 sept.  2 21:36 ./
# drwxr-xr-x 25 jerome jerome    4096 févr.  5  2017 ../
# -rw-r--r--  1 jerome jerome  518218 févr. 26  2017 18mm.jpg
# -rw-r--r--  1 jerome jerome 2376055 févr.  5  2017 g1.jpg
# -rw-r--r--  1 jerome jerome 2261608 févr.  5  2017 g2.jpg
# -rw-r--r--  1 jerome jerome 8660453 févr.  5  2017 g3.jpg
# -rw-------  1 jerome jerome 1172747 févr. 26  2017 grid-18mm.ipynb
# -rw-------  1 jerome jerome 1853587 mars  20 07:43 grid-18mm-raw.ipynb
# -rw-------  1 jerome jerome 1942311 sept.  2 21:36 grid_8M.ipynb
# -rw-r--r--  1 jerome jerome 4408397 sept.  2 16:17 grid-8M.jpg
# -rw-r--r--  1 jerome jerome 4299391 sept.  2 16:17 grid-8M_v2.jpg
# -rw-------  1 jerome jerome 1273545 mars  20 07:43 grid.ipynb
# -rw-r--r--  1 jerome jerome   54240 déc.  15  2016 grid.png
# drwxr-xr-x  2 jerome jerome    4096 sept.  2 16:22 .ipynb_checkpoints/
# -rw-r--r--  1 jerome photo  3953240 févr. 27  2017 raw_18mm.jpg
# -rw-r--r--  1 jerome photo     5879 févr. 27  2017 raw_18mm.jpg.out.pp3
# -rw-r--r--  1 jerome jerome 2252468 févr.  5  2017 snow.jpg

# %%
from scipy.misc import imread
raw = imread("grid-8M_v2.jpg", flatten=True)
print(raw)
# Out:
# [[ 113.86199951  112.86199951  107.86199951 ...,  133.15100098
#    133.15100098  132.15100098]
#  [ 114.7480011   114.7480011   113.7480011  ...,  133.15100098
#    133.15100098  132.15100098]
#  [ 124.16699982  124.16699982  128.16700745 ...,  132.92300415
#    129.93400574  128.93400574]
#  ...,
#  [ 138.91799927  143.91799927  151.91799927 ...,  119.17900085
#    118.17900085  116.9509964 ]
#  [ 145.14599609  145.14599609  146.14599609 ...,  118.9509964   118.94000244
#    121.71199799]
#  [ 148.14599609  145.14599609  144.14599609 ...,  117.9509964   121.71199799
#    119.71199799]]

# %%
figure()
imshow(raw, cmap="gray")
# Out:
# <img src="data:image/png;base64,...">

# %%
import silx.opencl.medfilt
#silx.opencl.medfilt.medfilt2d?

# %%
width=83

try:
    from silx.opencl import medfilt
except:
    print("using scipy")
    from scipy.ndimage import filters
    # %time flat = filters.median_filter(raw, width, mode="nearest")                     
else:
    print("using silx")
    # %time flat = medfilt.medfilt2d(raw, width)                     
#flat = filters.maximum_filter(raw, width, mode="nearest")
# Out:
# WARNING:silx.opencl.medfilt:max actual workgroup size: 1024, expected: 1024
# using silx
# CPU times: user 5min 18s, sys: 1min 9s, total: 6min 27s
# Wall time: 6min 27s
# <div id='20a487ac-6dab-4158-9fee-d3b18aaa856f'></div>

# %%
figure()
imshow(flat, cmap="gray")
colorbar()
# Out:
# <img src="data:image/png;base64,...">

# %%
figure()
fcor = raw/flat
img = (fcor.max() - fcor)/(fcor.max()-fcor.min())
imshow(img)
colorbar()
# Out:
# <img src="data:image/png;base64,...">

# %%
size = 17 #Odd of course
center = (size-1)//2
y, x = numpy.ogrid[-center:center+1,-center:center+1]
r2 = x*x + y*y
kernel = (r2<=(center+0.5)**2).astype(float)
kernel /= kernel.sum()
figure()
imshow(kernel, interpolation="nearest", origin="lower")
# Out:
# <img src="data:image/png;base64,...">

# %%
from scipy import ndimage, signal
cnv = signal.convolve2d(img, kernel, mode="same")

# %%
#Check that size is unchanged.
print(img.shape) 
print(cnv.shape)
# Out:
# (2464, 3280)
# (2464, 3280)

# %%
#Check the image still looks the same. it is just supposed to be smoother.
figure()
imshow(cnv, interpolation="nearest")
colorbar()
# Out:
# <img src="data:image/png;base64,...">

# %%
mini = (kernel>0).sum()
print("Number of points in the kernel: %s"%mini)
# Out:
# Number of points in the kernel: 225

# %%
try: #depends if the version of pyFAI you are using
    from pyFAI.watershed import InverseWatershed
except:
    from pyFAI.ext.watershed import InverseWatershed
    #Version of pyFAI newer than feb 2016
iw = InverseWatershed(cnv)
iw.init()
iw.merge_singleton()
all_regions = set(iw.regions.values())
regions = [i for i in all_regions if i.size>mini]

print("Number of region segmented: %s"%len(all_regions))
print("Number of large enough regions : %s"%len(regions))
# Out:
# Number of region segmented: 162694
# Number of large enough regions : 1759

# %%
s = [i.maxi for i in regions]
figure()
hist(s, 30)
#Look for the maximum value in each region to be able to segment accordingly
# Out:
# <img src="data:image/png;base64,...">
# (array([ 323.,    2.,    3.,    3.,    0.,    3.,    4.,    9.,   17.,
#           22.,   33.,   34.,   45.,   51.,   63.,   73.,   84.,  114.,
#          101.,   99.,   82.,  101.,   80.,   70.,   68.,   74.,   68.,
#           61.,   44.,   28.]),
#  array([ 0.14150685,  0.16283048,  0.1841541 ,  0.20547773,  0.22680135,
#          0.24812498,  0.2694486 ,  0.29077223,  0.31209585,  0.33341948,
#          0.3547431 ,  0.37606673,  0.39739035,  0.41871398,  0.4400376 ,
#          0.46136123,  0.48268485,  0.50400848,  0.52533211,  0.54665573,
#          0.56797936,  0.58930298,  0.61062661,  0.63195023,  0.65327386,
#          0.67459748,  0.69592111,  0.71724473,  0.73856836,  0.75989198,
#          0.78121561]),
#  <a list of 30 Patch objects>)

# %%
thres= 0.24
peaks = [(i.index//img.shape[-1], i.index%img.shape[-1]) for i in regions if (i.maxi)>thres]
print("Number of remaining peaks: %s"%len(peaks))
# Out:
# Number of remaining peaks: 1428

# %%
figure()
imshow(img, interpolation="nearest")
peaks_raw = numpy.array(peaks)
plot(peaks_raw[:,1], peaks_raw[:, 0], "or")
title("Extracted peak position (raw)")
print("Raw peak coordinate:")
print(peaks[:10])
# Out:
# <img src="data:image/png;base64,...">
# Raw peak coordinate:
# [(2126, 2850), (1768, 3263), (423, 1226), (188, 2557), (158, 1576), (833, 397), (390, 3089), (391, 71), (1591, 1361), (1770, 537)]

# %%
try:
    from pyFAI.bilinear import Bilinear
except:
    from pyFAI.ext.bilinear import Bilinear
bl = Bilinear(cnv)

# %%
figure()
ref_peaks = [bl.local_maxi(p) for p in peaks_raw]
imshow(img, interpolation="nearest")
peaks_ref = numpy.array(ref_peaks)
plot(peaks_raw[:,1], peaks_raw[:, 0], "or")
plot(peaks_ref[:,1],peaks_ref[:, 0], "ob")
title("Extracted peak position (red: raw, blue: refined)")
print("Refined peak coordinate:")
print(ref_peaks[:10])
# Out:
# <img src="data:image/png;base64,...">
# Refined peak coordinate:
# [(2126.2124168276787, 2850.028342390433), (1767.532812654972, 3262.920187778771), (423.11823558807373, 1226.300294160843), (188.19163535535336, 2557.506308197975), (157.5488161444664, 1575.734067350626), (832.6102851033211, 396.7752428352833), (389.70948046445847, 3088.848162382841), (391.46034172177315, 71.18242532014847), (1591.3859858810902, 1361.1837742775679), (1769.7416861951351, 537.1243727430701)]

# %%
# Nota, pyFAI uses **C-coordinates** so they come out as (y,x) and not the usual (x,y). 
# This notation helps us to remind the order
yx = numpy.array(ref_peaks)

# %%
# pairwise distance calculation using scipy.spatial.distance_matrix
from scipy.spatial import distance_matrix
dist = distance_matrix(peaks_ref, peaks_ref)

# %%
figure()
hist(dist.ravel(), 200, range=(0,200))
title("Pair-wise distribution function")
# Out:
# <img src="data:image/png;base64,...">

# %%
#We define here a data-type for each peak (called center) with 4 neighbours (called north, east, south and west). 
point_type = np.dtype([('center_y', float), ('center_x', float),
                        ('east_y', float), ('east_x', float),
                        ('west_y', float), ('west_x', float),
                        ('north_y', float), ('north_x', float),
                        ('south_y', float), ('south_x', float)])

neig = np.logical_and(dist>40.0, dist<93)
valid = (neig.sum(axis=-1)==4).sum()
print("There are %i control point with exactly 4 first neigbours"%valid)
# This initializes an empty structure to be populated
point = numpy.zeros(valid, point_type)
# Out:
# There are 897 control point with exactly 4 first neigbours

# %%
#Populate the structure: we use a loop as it loops only over 1200 points 
h=-1
for i, center in enumerate(peaks_ref):
    if neig[i].sum()!=4: continue
    h+=1
    point[h]["center_y"],point[h]["center_x"] = center
    for j in ((0,1),(0,-1),(1,0),(-1,0)):
        tmp = []
        for k in numpy.where(neig[i]):
            curr = yx[k]
            tmp.append(dot(curr-center,j))
            l = argmax(tmp)
            y, x = peaks_ref[numpy.where(neig[i])][l]
            if j==(0,1):point[h]["east_y"], point[h]["east_x"] = y, x
            elif j==(0,-1):point[h]["west_y"], point[h]["west_x"] = y, x
            elif j==(1,0): point[h]["north_y"],point[h]["north_x"] = y, x
            elif j==(-1,0):point[h]["south_y"],point[h]["south_x"] = y, x
all_points = point

# %%
figure()
ref_peaks = [bl.local_maxi(p) for p in peaks_raw]
imshow(img, interpolation="nearest")
#peaks_ref = numpy.array(ref_peaks)
plot(point[:]["center_x"], point[:]["center_y"], "or")
# Out:
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">

# %%
Cy, Cx = tuple(i//2 for i in cnv.shape) #detector center
print("The guessed center is at (%s, %s)"%(Cx, Cy))

t2 = 1300**2
point_mask = numpy.array([(i["center_x"]-Cx)**2+ (i["center_y"]-Cy)**2<t2 for i in point])
print(point_mask.sum())
figure()
ref_peaks = [bl.local_maxi(p) for p in peaks_raw]
imshow(img, interpolation="nearest")
point = point[point_mask]
plot(point[:]["center_x"], point[:]["center_y"], "or")
# Out:
# The guessed center is at (1640, 1232)
# 707
# <img src="data:image/png;base64,...">

# %%
#Select the initial guess for the center:

#Most intense peak:
#m = max([i for i in regions], key=lambda i:i.maxi)
#Cx, Cy = m.index%img.shape[-1],m.index//img.shape[-1]
#Cx, Cy = point["center_x"].mean(), point["center_y"].mean() #Centroid of all points
#Cx, Cy = 734, 1181 #beam center
Cy, Cx = tuple(i//2 for i in cnv.shape) #detector center
print("The guessed center is at (%s, %s)"%(Cx, Cy))

#Get the nearest point from centroid:
d2 = ((point["center_x"]-Cx)**2+(point["center_y"]-Cy)**2)
best = d2.argmin()
Op = point[best]
Ox, Oy = Op["center_x"], Op["center_y"]

print("The center is at (%s, %s)"%(Ox, Oy))
#Calculate the average vector along the 4 main axes 
Xx = (point[:]["east_x"] - point[:]["center_x"]).mean()
Xy = (point[:]["east_y"] - point[:]["center_y"]).mean()
Yx = (point[:]["north_x"] - point[:]["center_x"]).mean()
Yy = (point[:]["north_y"] - point[:]["center_y"]).mean()

print("The X vector is is at (%s, %s)"%(Xx, Xy))
print("The Y vector is is at (%s, %s)"%(Yx, Yy))
# Out:
# The guessed center is at (1640, 1232)
# The center is at (1616.37340328, 1219.28241038)
# The X vector is is at (82.6231872702, -3.30538006469)
# The Y vector is is at (3.69329921098, 83.2201820088)

# %%
print("X has an angle of %s deg"%rad2deg(arctan2(Xy, Xx)))
print("Y has an angle of %s deg"%rad2deg(arctan2(Yy, Yx)))
print("The XY angle is %s deg"%rad2deg(arctan2(Yy, Yx)-arctan2(Xy, Xx)))
# Out:
# X has an angle of -2.29092338259 deg
# Y has an angle of 87.4588893123 deg
# The XY angle is 89.7498126949 deg

# %%
from collections import namedtuple, OrderedDict
Peak = namedtuple("Peak", ('center_y', 'center_x'))
Coord = namedtuple("Coord", ('X', 'Y'))
dicopt = OrderedDict()

def nearest(pty,ptx):
    d2 = (point[:]['center_y']-pty)**2 +  (point[:]['center_x']-ptx)**2
    m = d2.argmin()
    if d2[m]<1:
        return point[m]

def add_nei(pt, coord):
    dicopt[coord]= Peak(pt[0],pt[1])
    east = nearest(pt[2],pt[3])
    east_coord = Coord(coord[0]+1, coord[1])
    if east is not None:
        if east_coord not in dicopt:
            add_nei(east, east_coord)
    else:
        dicopt[east_coord] = Peak(pt[2],pt[3])

    west = nearest(pt[4],pt[5])
    west_coord = Coord(coord[0]-1, coord[1])
    if west is not None:
        if west_coord not in dicopt:
            add_nei(west, west_coord)
    else:
        dicopt[west_coord] = Peak(pt[4],pt[5])

    south = nearest(pt[6],pt[7])
    south_coord = Coord(coord[0], coord[1]+1)
    if south is not None:
        if south_coord not in dicopt:
            add_nei(south, south_coord)
    else:
        dicopt[south_coord] = Peak(pt[6],pt[7])

    north = nearest(pt[8],pt[9])
    north_coord = Coord(coord[0], coord[1]-1)
    if north is not None:
        if north_coord not in dicopt:
            add_nei(north, north_coord)
    else:
        dicopt[north_coord] = Peak(pt[8],pt[9])


add_nei(Op, Coord(0,0))
print(len(dicopt))
# Out:
# 797

# %%
dataset = numpy.zeros((len(dicopt), 4))
for idx, (k,v) in enumerate(dicopt.items()):
    if idx<10:
        print("%s --> %s"%(k,v))
    dataset[idx,0] = k[0]
    dataset[idx,1] = k[1]
    dataset[idx,2] = v[1]
    dataset[idx,3] = v[0]
print(dataset[:5])
# Out:
# Coord(X=0, Y=0) --> Peak(center_y=1219.2824103832245, center_x=1616.3734032809734)
# Coord(X=1, Y=0) --> Peak(center_y=1215.3847859501839, center_x=1707.3232043981552)
# Coord(X=2, Y=0) --> Peak(center_y=1211.3218063116074, center_x=1797.9880517832935)
# Coord(X=3, Y=0) --> Peak(center_y=1207.2592997252941, center_x=1887.7213736474514)
# Coord(X=4, Y=0) --> Peak(center_y=1203.1817710846663, center_x=1976.3273874521255)
# Coord(X=5, Y=0) --> Peak(center_y=1199.1338409930468, center_x=2063.7423221170902)
# Coord(X=6, Y=0) --> Peak(center_y=1194.8155569583178, center_x=2149.5528848767281)
# Coord(X=7, Y=0) --> Peak(center_y=1190.7450001239777, center_x=2233.8074547201395)
# Coord(X=8, Y=0) --> Peak(center_y=1186.5063595175743, center_x=2316.5632177591324)
# Coord(X=9, Y=0) --> Peak(center_y=1182.6484205424786, center_x=2397.1312293112278)
# [[  0.00000000e+00   0.00000000e+00   1.61637340e+03   1.21928241e+03]
#  [  1.00000000e+00   0.00000000e+00   1.70732320e+03   1.21538479e+03]
#  [  2.00000000e+00   0.00000000e+00   1.79798805e+03   1.21132181e+03]
#  [  3.00000000e+00   0.00000000e+00   1.88772137e+03   1.20725930e+03]
#  [  4.00000000e+00   0.00000000e+00   1.97632739e+03   1.20318177e+03]]

# %%
def rotate(arg, data=dataset): 
    "Convert the XY (integrers) parameters in xy, pixel coordinates, without distortion, only rotation+translation"
    xc, yc, Xx, Yx, Xy, Yy, Xc, Yc = arg
    XYc = numpy.atleast_2d(numpy.array((Xc, Yc)))
    XY = (data[:,:2]-XYc).T
    #R = numpy.array([[Xx, Xy],[Yx, Yy]])
    R = numpy.array([[Xx, Yx], [Xy, Yy]])
    xyc = numpy.atleast_2d(numpy.array((xc, yc)))
    res = dot(R, XY).T + xyc
    return res 

def error_rot(arg, data=dataset):
    w = rotate(arg, data=data) 
    e = data[:,2:]
    d2 = (w-e)**2
    return numpy.sum(d2)

w = rotate([Ox, Oy, Xx, Yx, Xy, Yy, 0, 0], dataset) 
for i in range(5):
    print("%s %s "%(dataset[i,:], w[i,:]))

#mask = numpy.where(numpy.logical_and(abs(dataset[:,0])<5, abs(dataset[:,1])<5))
#print(mask[0], len(mask[0]))
#for i in mask[0]:
#    print(w[i], dataset[i,2:], ((w[i]-dataset[i,2:])**2).sum())
print(((w-dataset[:,2:])**2).sum())

print(error_rot((Ox, Oy, Xx,Yx, Xy, Yy, 0, 0)))
    
from scipy.optimize import minimize
res0 = [Ox, Oy, Xx, Yx, Xy, Yy, 0, 0]
print(res0)
bounds = [(1000,2000),(1000, 1500), (80,100), (-10, 10), (-10, 10), (80,100), 
          (-10, 10),(-10, 10)]
print(res0)
print(error_rot(res0))
res1  = minimize(error_rot, res0, bounds=bounds)
print(res1)
res1 = res1.x
# Out:
# [    0.             0.          1616.37340328  1219.28241038] [ 1616.37340328  1219.28241038]
# [  1.00000000e+00   0.00000000e+00   1.70732320e+03   1.21538479e+03] [ 1698.99659055  1215.97703032]
# [    2.             0.          1797.98805178  1211.32180631] [ 1781.61977782  1212.67165025]
# [    3.             0.          1887.72137365  1207.25929973] [ 1864.24296509  1209.36627019]
# [    4.             0.          1976.32738745  1203.18177108] [ 1946.86615236  1206.06089012]
# 1400048.97046
# 1400048.97046
# [1616.3734032809734, 1219.2824103832245, 82.623187270236784, 3.6932992109814147, -3.3053800646928493, 83.220182008827905, 0, 0]
# [1616.3734032809734, 1219.2824103832245, 82.623187270236784, 3.6932992109814147, -3.3053800646928493, 83.220182008827905, 0, 0]
# 1400048.97046
#        x: array([  1.58084501e+03,   1.20664320e+03,   8.47091613e+01,
#          3.67385907e+00,  -3.39515343e+00,   8.51857777e+01,
#         -3.11622472e-01,   2.75507676e-04])
#      nit: 25
#     nfev: 300
#  success: True
#  message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      jac: array([ -1.28056854e-01,  -1.16415322e-02,  -7.91624188e-01,
#         -7.45058060e-01,  -4.99421731e+00,  -2.98023224e+00,
#          1.21304765e+01,  -1.43190846e+00])
#      fun: 776942.16984546173
#   status: 0

# %%
from scipy.optimize import minimize

def wrapd1(arg, data=dataset):
    d = data[:,2:]
    
    c = numpy.atleast_2d(numpy.array((arg[0], arg[1])))
    r1 =((d - c)**2).sum(axis=-1)
    r2 = numpy.atleast_2d(r1).T
    #for i in zip(dataset, r2, range(10)):
    #    print(i[0], i[1])
    K1 = arg[8]*1e-9
    return c + (d-c)/(1.0+K1*r2)

def unwrapd1(arg, data=dataset):
    "convert indexes to distorted position"
    u = rotate(arg[:8], data=data) 
    c = numpy.atleast_2d(numpy.array((arg[0], arg[1])))
    r1 =((u - c)**2).sum(axis=-1)
    r2 = numpy.atleast_2d(r1).T
    #for i in zip(dataset, r2, range(10)):
    #    print(i[0], i[1])
    K1 = arg[8]*1e-9
    return c + (u - c)*(1+K1*r2)
    #return c + (d-c)/(1.0+K1*r2)


def errord1(arg, data=dataset):
    w = wrapd1(arg, data=data) 
    u = rotate(arg[:8]) 
    d2 = (w-u)**2
    return numpy.sum(d2)

def errord1u(arg, data=dataset):
    ex = unwrapd1(arg, data=data) 
    di = data[:,2:]
    d2 = (ex-di)**2
    return numpy.sum(d2)


res1d1=list(res1)+[0]
print(errord1(res0d1))

boundsd1 = [(i,i) for i in res1] + [(-10,10)]

#Does not work very well
res1d1  = minimize(errord1, res0d1, bounds=boundsd1)
print(res1d1)

res1d1u  = minimize(errord1u, res0d1, bounds=boundsd1)
print(res1d1u)

bounds2d1 = bounds + [(-100,100)]
print(len(bounds2d1), len(res1d1.x))

res2d1  = minimize(errord1, res1d1.x, bounds=bounds2d1)
print(res2d1)

res2d1u  = minimize(errord1u, res1d1u.x, bounds=bounds2d1)
print(res2d1u)

#bounds[6] = res1[6], res1[6]
#bounds[7] = res1[7], res1[7]
#bounds[11] = -1.1,1.1
#bounds[10] = -1.1,1.1
#print(errord1(res1d1.x))
#res2  = minimize(error, res1, bounds=bounds)
#print(res2)
# Out:
# 776942.169692
#        x: array([  1.58084501e+03,   1.20664320e+03,   8.47091613e+01,
#          3.67385907e+00,  -3.39515343e+00,   8.51857777e+01,
#         -3.11622472e-01,   2.75507676e-04,  -5.89709440e+00])
#      nit: 4
#     nfev: 495
#  success: False
#  message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      jac: array([ -6.96349889e+02,   1.49558764e+02,  -6.89993962e+04,
#          4.00480349e+03,   9.24065243e+03,  -5.69027965e+04,
#          7.15477392e+04,   4.98645240e+03,   2.32830644e-02])
#      fun: 734727.14530621306
#   status: 2
#        x: array([  1.58084501e+03,   1.20664320e+03,   8.47091613e+01,
#          3.67385907e+00,  -3.39515343e+00,   8.51857777e+01,
#         -3.11622472e-01,   2.75507676e-04,  -7.19442693e+00])
#      nit: 3
#     nfev: 55
#  success: True
#  message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      jac: array([ -1.23992795e+03,  -2.38150824e+02,  -8.64439644e+04,
#          5.16611617e+03,   1.17107993e+04,  -7.03432481e+04,
#          1.18270400e+05,   4.32887231e+04,  -8.14907253e-02])
#      fun: 708445.02038125903
#   status: 0
# 9 9
#        x: array([ 1477.52047052,  1037.8802184 ,    91.84762728,     3.96477243,
#           -3.68010062,    92.1042986 ,    -1.49497761,    -2.08312363,
#          -57.58821657])
#      nit: 129
#     nfev: 1661
#  success: True
#  message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      jac: array([ 0.09385985,  0.18262654,  0.44819899,  0.28448994,  5.27361408,
#         4.55838745, -1.8888386 , -5.84041118,  0.8934876 ])
#      fun: 37538.204236589285
#   status: 0
#        x: array([  1.48862005e+03,   1.04648383e+03,   9.11174237e+01,
#          3.92402781e+00,  -3.64772498e+00,   9.13716654e+01,
#         -1.36788321e+00,  -1.97619774e+00,  -4.43215638e+01])
#      nit: 137
#     nfev: 1727
#  success: True
#  message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      jac: array([ 0.0167347 ,  0.01891749,  0.61627361, -0.32887328,  2.07073754,
#         0.26702764, -1.7847924 , -1.48284016,  0.39581209])
#      fun: 33031.756608269221
#   status: 0

# %%
fitted = unwrapd1(res2d1u.x)
f = figure()
ax = f.add_subplot(1,1,1)
ax.imshow(cnv, interpolation="nearest")
for k, ds, w in zip(dicopt, dataset, fitted):
    ax.annotate("%i,%i"%k, xy=ds[2:], xytext=w,
                arrowprops=dict(facecolor='red', edgecolor='red'))
# Out:
# <img src="data:image/png;base64,...">

# %%
import itertools
all_idx_12 = numpy.array(list(itertools.product(range(-13, 14),range(-13,14))),dtype="float64")
print(len(all_idx_12))
fitted_12 = unwrapd1(res2d1u.x, data=all_idx_12)
print(len(dataset), len(fitted_12))
f,ax = subplots()
ax.imshow(cnv, interpolation="nearest")
plot(peaks_ref[:,1],peaks_ref[:, 0], ".g")
plot(fitted_12[:,0], fitted_12[:,1],".r")
# Out:
# 729
# 797 729
# <img src="data:image/png;base64,...">

# %%
from scipy.spatial.distance import cdist
peaks_ref_xy = numpy.zeros_like(peaks_ref)
peaks_ref_xy[:,0] = peaks_ref[:,1]
peaks_ref_xy[:,1] = peaks_ref[:,0]
all_dist_12 = cdist(fitted_12, peaks_ref_xy,  'euclidean')
print(all_dist_12.shape)
dmin = all_dist_12.min(axis=1)
amin = all_dist_12.argmin(axis=1)
msk = dmin<40
print(msk.sum())
dataset_12 = numpy.zeros((msk.sum(), 4))
dataset_12[:,:2] = all_idx_12[msk]
dataset_12[:,2:] = peaks_ref_xy[amin[msk]]

# def unwrapd2(arg, data=dataset):
#     "convert indexes to distorted position"
#     u = rotate(arg[:8], data=data) 
#     c = numpy.atleast_2d(numpy.array((arg[0], arg[1])))
#     r1 =((u - c)**2).sum(axis=-1)
#     r2 = numpy.atleast_2d(r1).T
#     #for i in zip(dataset, r2, range(10)):
#     #    print(i[0], i[1])
#     K1 = arg[8]*1e-9
#     K2 = arg[9]*1e-12
#     return c + (u - c)*(1+K1*r2+K2*r2*r2)


# def errord2u(arg, data=dataset):
#     ex = unwrapd2(arg, data=data) 
#     di = data[:,2:]
#     d2 = (ex-di)**2
#     return numpy.sum(d2)


print(errord1u(list(res2d1u.x), data=dataset_12))
# fitted_12 = unwrapd1(list(res2d1u.x), data=dataset_12)
for i in zip(range(10), dataset_12, fitted_12):
        print(i[0], i[1], i[2])
f,ax = subplots()
ax.imshow(cnv, interpolation="nearest")
plot(fitted_12[:,0], fitted_12[:,1],".r")
plot(peaks_ref_xy[:,0],peaks_ref_xy[:, 1], ".g")
for ds, w in zip(dataset_12, fitted_12):
    ax.annotate("", xy=ds[2:], xytext=w,
                arrowprops=dict(facecolor='red', edgecolor='red'))
# Out:
# (729, 1428)
# 729
# 24404.2981316
# 0 [ -13.          -13.          495.63110971  171.44868225] [ 490.48819171  173.49896073]
# 1 [ -13.          -12.          489.77761458  248.28115436] [ 485.43436129  249.33533965]
# 2 [ -13.          -11.          484.95520993  326.73202014] [ 481.25404621  327.18202846]
# 3 [ -13.          -10.          481.13443068  407.00973872] [ 477.93851834  406.8357909 ]
# 4 [ -13.           -9.          478.96260961  489.04338329] [ 475.47904954  488.09339072]
# 5 [ -13.           -8.          477.25951973  571.94988868] [ 473.86691166  570.75159164]
# 6 [ -13.           -7.          474.37661186  655.65329671] [ 473.09337657  654.60715741]
# 7 [ -13.           -6.          472.34286669  740.0728297 ] [ 473.14971612  739.45685178]
# 8 [ -13.           -5.          471.66598949  826.13375017] [ 474.02720218  825.09743847]
# 9 [ -13.           -4.          473.04332503  913.03183185] [ 475.7171066   911.32568122]
# <img src="data:image/png;base64,...">

# %%
def unwrapd2(arg, data=dataset):
    "convert indexes to distorted position"
    u = rotate(arg[:8], data=data) 
    c = numpy.atleast_2d(numpy.array((arg[0], arg[1])))
    r1 =((u - c)**2).sum(axis=-1)
    r2 = numpy.atleast_2d(r1).T
    #for i in zip(dataset, r2, range(10)):
    #    print(i[0], i[1])
    K1 = arg[8]*1e-9
    K2 = arg[9]*1e-12
    return c + (u - c)*(1+K1*r2+K2*r2*r2)


def errord2u(arg, data=dataset):
    ex = unwrapd2(arg, data=data) 
    di = data[:,2:]
    d2 = (ex-di)**2
    return numpy.sum(d2)

print(unwrapd2(list(res2d1u.x)+[0], dataset_12))
print(errord2u(list(res2d1u.x)+[0], dataset_12))
res12d2u  = minimize(errord2u, list(res2d1u.x)+[0], bounds=bounds2d2, args=(dataset_12,))
print(res12d1u)
fitted_12r =  unwrapd2(res12d2u.x, data=dataset_12)
f,ax = subplots()
ax.imshow(cnv, interpolation="nearest")
plot(peaks_ref_xy[:,0],peaks_ref_xy[:, 1], ".b")
plot(fitted_12[:,0], fitted_12[:,1],".r")
for ds, w in zip(dataset_12, fitted_12r):
    ax.annotate("", xy=ds[2:], xytext=w,
                arrowprops=dict(facecolor='red', edgecolor='red'))
# Out:
# [[  490.48819171   173.49896073]
#  [  485.43436129   249.33533965]
#  [  481.25404621   327.18202846]
#  ...,
#  [ 2659.77824739  2022.31451911]
#  [ 2649.48643434  2088.72027235]
#  [ 2638.10174279  2152.31876994]]
# 24404.2981316
#        x: array([  1.48828558e+03,   1.04570385e+03,   9.18115655e+01,
#          3.87118393e+00,  -3.72858273e+00,   9.21078361e+01,
#         -1.36281147e+00,  -1.97595603e+00,  -5.54956333e+01,
#          3.84009966e-03])
#      nit: 89
#     nfev: 1356
#  success: True
#  message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      jac: array([ 11.68009476,  20.77595127,  -5.69216354,  -5.56410669,
#          2.27246346,   6.14181772,  72.18095561,   6.13181328,
#         -1.62181095, -46.64543667])
#      fun: 13144.062924678949
#   status: 0
# <img src="data:image/png;base64,...">

# %%
all_idx_15 = numpy.array(list(itertools.product(range(-15, 16),range(-15, 16)))).astype("float64")
print(len(all_idx_15), len(peaks_ref_xy))
expected_15 = unwrapd2(res12d2u.x, data=all_idx_15)
all_dist_15 = cdist(expected_15, peaks_ref_xy,  'euclidean')
print(all_dist_15.shape)
dmin = all_dist_15.min(axis=1)
amin = all_dist_15.argmin(axis=1)
msk = dmin<40
print(msk.sum())
dataset_15 = numpy.zeros((msk.sum(), 4))
dataset_15[:,:2] = all_idx_15[msk]
dataset_15[:,2:] = peaks_ref_xy[amin[msk]]


print(errord2u(list(res12d2u.x), data=dataset_15))

res15d2u  = minimize(errord2u, res12d2u.x, bounds=bounds2d2, args=(dataset_15,))
print(res15d2u)
fitted_15 =  unwrapd2(res15d2u.x, data=dataset_15)

f,ax = subplots()
ax.imshow(cnv, interpolation="nearest")
plot(fitted_15[:,0], fitted_15[:,1],".r")
plot(peaks_ref_xy[:,0],peaks_ref_xy[:, 1], ".g")
for ds, w in zip(dataset_15, fitted_15):
    ax.annotate("", xy=ds[2:], xytext=w,
                arrowprops=dict(facecolor='red', edgecolor='red'))
# Out:
# 961 1428
# (961, 1428)
# 936
# 39725.2047005
#        x: array([  1.48844428e+03,   1.04607653e+03,   9.18332446e+01,
#          3.93133456e+00,  -3.72414360e+00,   9.21512833e+01,
#         -1.38096470e+00,  -1.98687900e+00,  -5.48687147e+01,
#          3.44588405e-03])
#      nit: 63
#     nfev: 972
#  success: True
#  message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      jac: array([ -1.96130713e+01,  -2.28064891e+01,   1.10200199e+02,
#         -3.39176040e+01,  -9.13722033e+01,   4.47776983e+01,
#          1.08630047e+00,  -1.44187652e+01,  -2.65351264e+02,
#          2.23246752e+03])
#      fun: 37240.831981805735
#   status: 0
# <img src="data:image/png;base64,...">

# %%
all_idx_17 = numpy.array(list(itertools.product(range(-17, 18),range(-17, 18)))).astype("float64")
print(len(all_idx_17), len(peaks_ref_xy))
expected_17 = unwrapd2(res15d2u.x, data=all_idx_17)
all_dist_17 = cdist(expected_17, peaks_ref_xy,  'euclidean')
print(all_dist_17.shape)
dmin = all_dist_17.min(axis=1)
amin = all_dist_17.argmin(axis=1)
msk = dmin<40
print(msk.sum())
dataset_17 = numpy.zeros((msk.sum(), 4))
dataset_17[:,:2] = all_idx_17[msk]
dataset_17[:,2:] = peaks_ref_xy[amin[msk]]


print(errord2u(list(res15d2u.x), data=dataset_17))

res17d2u  = minimize(errord2u, res15d2u.x, bounds=bounds2d2, args=(dataset_17,))
print(res17d2u)
fitted_17 =  unwrapd2(res17d2u.x, data=dataset_17)

f,ax = subplots()
ax.imshow(cnv, interpolation="nearest")
plot(fitted_17[:,0], fitted_17[:,1],".r")
plot(peaks_ref_xy[:,0],peaks_ref_xy[:, 1], ".g")
for ds, w in zip(dataset_17, fitted_17):
    ax.annotate("", xy=ds[2:], xytext=w,
                arrowprops=dict(facecolor='red', edgecolor='red'))
# Out:
# 1225 1428
# (1225, 1428)
# 1085
# 57581.0014873
#        x: array([  1.48854501e+03,   1.04619699e+03,   9.16735095e+01,
#          3.95405383e+00,  -3.72321593e+00,   9.19615462e+01,
#         -1.38438682e+00,  -1.99401985e+00,  -5.29293022e+01,
#          2.94384885e-03])
#      nit: 211
#     nfev: 3048
#  success: True
#  message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      jac: array([ -40.05778464,  -31.70061973,   19.40206857,  -14.46387614,
#          26.77188604,  -18.17170414,  -70.81252988, -366.96874304,
#           3.844616  , -659.64995883])
#      fun: 54492.293549874441
#   status: 0
# <img src="data:image/png;base64,...">

# %%
all_idx_20 = numpy.array(list(itertools.product(range(-19, 20),range(-19, 20)))).astype("float64")
print(len(all_idx_20), len(peaks_ref_xy))
expected_20 = unwrapd2(res17d2u.x, data=all_idx_20)
all_dist_20 = cdist(expected_20, peaks_ref_xy,  'euclidean')
print(all_dist_20.shape)
dmin = all_dist_20.min(axis=1)
amin = all_dist_20.argmin(axis=1)
msk = dmin<30
print(msk.sum())
dataset_20 = numpy.zeros((msk.sum(), 4))
dataset_20[:,:2] = all_idx_20[msk]
dataset_20[:,2:] = peaks_ref_xy[amin[msk]]


print(errord2u(list(res17d2u.x), data=dataset_20))

res20d2u  = minimize(errord2u, res17d2u.x, bounds=bounds2d2, args=(dataset_20,))
print(res20d2u)
fitted_20 =  unwrapd2(res20d2u.x, data=dataset_20)

f,ax = subplots()
ax.imshow(cnv, interpolation="nearest")
plot(fitted_20[:,0], fitted_20[:,1],".r")
plot(peaks_ref_xy[:,0],peaks_ref_xy[:, 1], ".g")
for ds, w in zip(dataset_20, fitted_20):
    ax.annotate("", xy=ds[2:], xytext=w,
                arrowprops=dict(facecolor='red', edgecolor='red'))
# Out:
# 1521 1428
# (1521, 1428)
# 1223
# 76623.8647334
#        x: array([  1.48854585e+03,   1.04619926e+03,   9.17658164e+01,
#          3.95518433e+00,  -3.73464777e+00,   9.20288628e+01,
#         -1.38858316e+00,  -2.00402705e+00,  -5.28762484e+01,
#          2.83660862e-03])
#      nit: 23
#     nfev: 420
#  success: True
#  message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      jac: array([  -47.57603165,  -111.79363355,   975.1325706 ,  -709.5921319 ,
#          924.17321866,   -85.65111784,  -105.74003682,   126.6162144 ,
#        -1409.97726703, -6646.13617118])
#      fun: 73809.486090773149
#   status: 0
# <img src="data:image/png;base64,...">

# %%
all_idx_30 = numpy.array(list(itertools.product(range(-30, 31),range(-30, 31)))).astype("float64")
print(len(all_idx_30), len(peaks_ref_xy))
expected_30 = unwrapd2(res20d2u.x, data=all_idx_30)
all_dist_30 = cdist(expected_30, peaks_ref_xy,  'euclidean')
print(all_dist_30.shape)
dmin = all_dist_30.min(axis=1)
amin = all_dist_30.argmin(axis=1)
msk = dmin<30
print(msk.sum())
dataset_30 = numpy.zeros((msk.sum(), 4))
dataset_30[:,:2] = all_idx_30[msk]
dataset_30[:,2:] = peaks_ref_xy[amin[msk]]


print(errord2u(list(res20d2u.x), data=dataset_30))

res30d2u  = minimize(errord2u, res20d2u.x, bounds=bounds2d2, args=(dataset_30,))
print(res30d2u)
fitted_30 =  unwrapd2(res30d2u.x, data=dataset_30)

f,ax = subplots()
ax.imshow(cnv, interpolation="nearest")
plot(fitted_30[:,0], fitted_30[:,1],".r")
plot(peaks_ref_xy[:,0],peaks_ref_xy[:, 1], ".g")
for ds, w in zip(dataset_30, fitted_30):
    ax.annotate("", xy=ds[2:], xytext=w,
                arrowprops=dict(facecolor='red', edgecolor='red'))
# Out:
# 3721 1428
# (3721, 1428)
# 1400
# 123056.574337
#        x: array([  1.48854773e+03,   1.04621511e+03,   9.17716316e+01,
#          3.95613222e+00,  -3.68528743e+00,   9.20653907e+01,
#         -1.39406350e+00,  -2.01676173e+00,  -5.27574415e+01,
#          2.78586398e-03])
#      nit: 52
#     nfev: 804
#  success: True
#  message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      jac: array([  -36.05528036,  -266.61437005, -1441.48507388,   509.86272981,
#          -18.66574166,  4401.40429419,   307.45140975,   882.84577942,
#        -1271.25094878, -1854.88315765])
#      fun: 119770.1241770429
#   status: 0
# <img src="data:image/png;base64,...">

# %%
all_idx_31 = numpy.array(list(itertools.product(range(-31, 32),range(-31, 32)))).astype("float64")
print(len(all_idx_31), len(peaks_ref_xy))
expected_31 = unwrapd2(res30d2u.x, data=all_idx_31)
all_dist_31 = cdist(expected_31, peaks_ref_xy,  'euclidean')
print(all_dist_31.shape)
dmin = all_dist_31.min(axis=1)
amin = all_dist_31.argmin(axis=1)
msk = dmin<20
print(msk.sum())
dataset_31 = numpy.zeros((msk.sum(), 4))
dataset_31[:,:2] = all_idx_31[msk]
dataset_31[:,2:] = peaks_ref_xy[amin[msk]]


print(errord2u(list(res31d2u.x), data=dataset_31))

res31d2u  = minimize(errord2u, res31d2u.x, bounds=bounds2d2, args=(dataset_31,))
print(res31d2u)
fitted_31 =  unwrapd2(res31d2u.x, data=dataset_31)

f,ax = subplots()
ax.imshow(cnv, interpolation="nearest")
plot(fitted_31[:,0], fitted_31[:,1],".r")
plot(peaks_ref_xy[:,0],peaks_ref_xy[:, 1], ".g")
for ds, w in zip(dataset_31, fitted_31):
    ax.annotate("", xy=ds[2:], xytext=w,
                arrowprops=dict(facecolor='red', edgecolor='red'))
# Out:
# 3969 1428
# (3969, 1428)
# 1338
# 82671.8698718
#        x: array([  1.48859777e+03,   1.04644920e+03,   9.15378668e+01,
#          3.94031565e+00,  -3.66548711e+00,   9.17961461e+01,
#         -1.38774794e+00,  -2.00607289e+00,  -5.13562008e+01,
#          2.57869776e-03])
#      nit: 1
#     nfev: 36
#  success: True
#  message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      jac: array([  27.9978849 , -111.82855815, -490.35443226,  309.06958273,
#         269.80123948,  651.01485234,  139.29820852,  326.45475585,
#         365.23124436,   12.86825864])
#      fun: 82671.869850218791
#   status: 0
# <img src="data:image/png;base64,...">

# %%
def correct2(coord, arg=res31d2u.x):
    "convert position to distorted position"
    c0, c1 = arg[:2]
    u0, u1 = coord
    r2 =(c0 - u0)**2 + (c1 - u1)**2
    K1 = arg[8]*1e-9
    K2 = arg[9]*1e-12
    cor = (1+K1*r2+K2*r2*r2)
    return (c0 + (u0 - c0)*cor, c1 + (u1 - c1)*cor)
from scipy.ndimage import geometric_transform
corrected =  geometric_transform(cnv, correct2)

# %%
f,ax = subplots()
ax.imshow(corrected)
# Out:
# <img src="data:image/png;base64,...">
